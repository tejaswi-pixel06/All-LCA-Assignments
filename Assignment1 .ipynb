# %%
print("To Create, Appened And Remove Dictionary")
dict={"Name":"Tejaswi","Age":"18"}
print("Original Dictionary:",dict)
dict.update({"DOB":"1 jan"})
print("After Adding :", dict)
del dict["DOB"]
print("After deleting :",dict)
# Out:
# To Create, Appened And Remove Dictionary
# Original Dictionary: {'Name': 'Tejaswi', 'Age': '18'}
# After Adding : {'Name': 'Tejaswi', 'Age': '18', 'DOB': '1 jan'}
# After deleting : {'Name': 'Tejaswi', 'Age': '18'}

# %%
print("to create tuple")
tuple=(1,2,3,4,5)
print("original tuple:",tuple)
# Out:
# to create tuple
# original tuple: (1, 2, 3, 4, 5)

# %%
print("To Create List")
list=[1,2,3,4,5]
print("list:",list)
# Out:
# To Create List
# list: [1, 2, 3, 4, 5]
