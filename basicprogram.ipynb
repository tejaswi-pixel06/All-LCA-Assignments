# %%
#printing hello world
print("Hello,World!")
# Out:
# Hello,World!

# %%
#finding largest in 3 numbers
a=int(input("enter no.-"))
b=int(input("enter no.-"))
c=int(input("enter no.-"))
if a>=c and a>=b :
 print("the largest no. is", a)
elif b>=c:
 print("the largest no. is",b)
else :
   print("the largest no. is", c)
# Out:
# enter no.- 5
# enter no.- 5
# enter no.- 6
# the largest no. is 6

# %%
#accepting 2 no. from user and sum of them
a=int(input("enter the number"))
b=int(input("enter the number"))
sum = a+b
print("the sum of given number is",sum )
# Out:
# enter the number 4
# enter the number 6
# the sum of given number is 10

# %%
#to tell whether no. is even or odd
n=int(input("enter the number:"))
if n%2 == 0:
      print("even")
else: 
      print("odd")

# %%
#building calculator
a=int(input("enter your no."))
b=int(input("enter your no."))
sum=(a+b)
print("the sum of given twp no. is",sum)
difference=(a-b)
print("the difference of two given no. is", difference)
div=a/b
print("the division of two give no. is", div)
multiple=a*b
print("the multilplication of two given no. is", multiple)
# Out:
# enter your no. 7
# enter your no. 14
# the sum of given twp no. is 21
# the difference of two given no. is -7
# the division of two give no. is 0.5
# the multilplication of two given no. is 98

# %%
#to check the no. is positive, negative or zero
a=float(input("enter the number:"))
if a>0 :
 print("postive")
elif a==0:
 print("zero")
else: 
 print("negtive")
# Out:
# enter the number: -5
# negtive

# %%
#sum of all digits of no.
n=int(input("enter the number:"))
sum=0
while n>0:
    digit = n % 10
    sum= sum + digit
    n=n // 10
    
print("sum of digits is: ", sum)
# Out:
# enter the number: 89767543
# sum of digits is:  49

# %%
#factorial
num = int(input("enter a number."))
factorial = 1
for i in range (1, num+1):
 factorial= factorial*i
print("Factorial=", factorial)
# Out:
# enter a number. 5
# Factorial= 120

# %%
#cube
a=int(input("enter the no."))
cube=(a*a*a)
print("the cube is:",cube)
# Out:
# enter the no. 5
# the cube is: 125

# %%
#reserving the no.
n=int(input("enter the number"))
reverse=0
while n>0:
    digit =n%10
    reverse=reverse*10 +digit
    n=n//10
print("reverse=",reverse)
# Out:
# enter the number 90
# reverse= 9

# %%
# check if a year is a leap year
year = int(input("enter the year: "))

if (year % 400 == 0) or (year % 4 == 0 and year % 100 != 0):
    print("Leap year")
else:
    print("Not a leap year")
# Out:
# enter the year:  7089
# Not a leap year

# %%
#student information (a)
student_name=str(input("enter the name"))
address=str(input("enter the address"))
contact_number =int(input("enter the phone no."))
mother_tongue=str(input("enter the mother tongue"))
school_name=str(input("enter the school name"))
year=int(input("enter the year"))
panel=str(input("enter the panel"))
roll_number=int(input("enter the roll no."))
# Out:
# enter the name tejaswi
# enter the address 23
# enter the phone no. 3243424
# enter the mother tongue adfjkj
# enter the school name dsfsdgfd
# enter the year 324
# enter the panel fsd
# enter the roll no. 23435

# %%
#(b)
#student information 
student_name=str(input("enter the name"))
'''
address=str(input("enter the address"))
contact_number =int(input("enter the phone no."))
mother_tongue=str(input("enter the mother tongue"))
'''
school_name=str(input("enter the school name"))
year=int(input("enter the year"))
panel=str(input("enter the panel"))
roll_number=int(input("enter the roll no."))
# Out:
# enter the name eirjfdslk
# enter the school name edfjnksd
# enter the year 32432
# enter the panel dsfs
# enter the roll no. 3243

# %%
#prime
n=int(input("enter the number"))
if n<=1:
 print("the number is not prime")
else:
    prime= True
    for i in range (2,n):
     if n % i==0:
         prime = False
         break
if prime:
    print("the number is prime.")
else:
    print("the number is not prime.")
# Out:
# enter the number 7
# the number is prime.
